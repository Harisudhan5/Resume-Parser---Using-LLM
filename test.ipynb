# %% [markdown]
# ## Fitz

# %%
import fitz 

def extract_pdf_structure(pdf_path):
    doc = fitz.open(pdf_path)
    
    document_structure = []

    for page_num in range(doc.page_count):
        page_structure = {
            'page_number': page_num + 1,
            'elements': []
        }
        page = doc[page_num]
        
        # Extract text blocks
        for block_num, block in enumerate(page.get_text("blocks")):
            text_block = {
                'type': 'text',
                'block_number': block_num + 1,
                'text': block[4],
                'font': block[0],
                'font_size': block[1],
                'rect': block[2]
            }
            page_structure['elements'].append(text_block)

        # Extract images
        for img_num, img in enumerate(page.get_images(full=True)):
            image_block = {
                'type': 'image',
                'image_number': img_num + 1,
                'image_rect': img[0],
                'image_width': img[1],
                'image_height': img[2],
                'image_colorspace': img[3],
            }
            page_structure['elements'].append(image_block)

        document_structure.append(page_structure)

    doc.close()

    return document_structure

pdf_path = "Your resume path :::::"
structure = extract_pdf_structure(pdf_path)

for page_info in structure:
    print(f"Page {page_info['page_number']}")
    for element_info in page_info['elements']:
        if element_info['type'] == 'text':
            print(f"  Text Block {element_info['block_number']}")
            print(f"    Text: {element_info['text']}")
            print(f"    Font: {element_info['font']}")
            print(f"    Font Size: {element_info['font_size']}")
            print(f"    Rectangle: {element_info['rect']}")
        elif element_info['type'] == 'image':
            print(f"  Image {element_info['image_number']}")
            print(f"    Rectangle: {element_info['image_rect']}")
            print(f"    Width: {element_info['image_width']}")
            print(f"    Height: {element_info['image_height']}")
            print(f"    Colorspace: {element_info['image_colorspace']}")
        print()
# Out:
# Page 1
#   Text Block 1
#     Text: PROJECTS
#
#     Font: 286.5746154785156
#     Font Size: 533.1427001953125
#     Rectangle: 363.97869873046875
#
#   Text Block 2
#     Text: <image: DeviceRGB, width: 728, height: 800, bpc: 8>
#     Font: 537.3345336914062
#     Font Size: 61.19999694824219
#     Rectangle: 550.0845336914062
#
#   Text Block 3
#     Text: SUMMARY
#
#     Font: 264.43792724609375
#     Font Size: 158.79612731933594
#     Rectangle: 347.55181884765625
#
#   Text Block 4
#     Text: PROFESSIONAL EXPERIENCE
# EDUCATION
#
#     Font: 57.81295394897461
#     Font Size: 245.1464080810547
#     Rectangle: 503.86553955078125
#
#   Text Block 5
#     Text: SKILLS
#
#     Font: 57.81295394897461
#     Font Size: 368.6838684082031
#     Rectangle: 110.10291290283203
#
#   Text Block 6
#     Text: CERTIFICATIONS
#
#     Font: 55.7723388671875
#     Font Size: 525.0294799804688
#     Rectangle: 186.49436950683594
#
#   Text Block 7
#     Text: speaktoharisudhan@gmail.com
#
#     Font: 364.084716796875
#     Font Size: 80.37564849853516
#     Rectangle: 526.7014770507812
#
#   Text Block 8
#     Text: +91 8438541785
# HARISUDHAN.S
#
#     Font: 68.88227844238281
#     Font Size: 40.9105224609375
#     Rectangle: 526.1234741210938
#
#   Text Block 9
#     Text: STUDENT
#
#     Font: 68.88227844238281
#     Font Size: 88.36264038085938
#     Rectangle: 130.45449829101562
#
#   Text Block 10
#     Text: Highly motivated Data science graduate with strong foundation in Python to work with data related projects and
# gained some practical experience in  internships.Passionate about learning skills and working with  real - world
# problems. Proficient in libraries required for data handling  ,preprocessing, analysis and basic concepts of neural
# networks, in deep learning,image processing by undergoing handson - projects to demonstrate my knowledge.
#
#     Font: 59.521480560302734
#     Font Size: 185.46890258789062
#     Rectangle: 551.3262329101562
#
#   Text Block 11
#     Text: During my first internship I gained knowledge of Python and its
# dominance in various domain and came across basics to integrating
# python with other tools and worked on object oriented programming
# project to setup a graphical user interface timer application.Later
# started to get proficient in functions ,discovering lmportantibraries.
#
#     Font: 289.0247802734375
#     Font Size: 472.9669189453125
#     Rectangle: 545.8592529296875
#
#   Text Block 12
#     Text: As a project intern I came through various machine learning
# algorithms and assigned to work on specific set of projects to
# analyze  the data and construct models for the use - case. First
# project was to analyze the flight dataset and to predict the flight
# delay time and the second project was to create a model which
# takes image as input and gives gender and age as output.
#
#     Font: 286.5746154785156
#     Font Size: 353.2288513183594
#     Rectangle: 534.6488037109375
#
#   Text Block 13
#     Text: Bachelor's Degree in Artificial Intelligence
# and  Data Science . CGPA - 8.9
# 2021 - 2025
#
#     Font: 57.81295394897461
#     Font Size: 287.61376953125
#     Rectangle: 222.1293182373047
#
#   Text Block 14
#     Text: HSE & SSLC
# 2020 – 2022
#
#     Font: 57.81295394897461
#     Font Size: 340.37646484375
#     Rectangle: 104.93688201904297
#
#   Text Block 15
#     Text: Python
# SQL
# Frontend Development
# Data Analysis
# Image Processing
# Flask Framework
# Machine Learning Techniques
# Computer Vision
# Deep Learning
# Web Scrapping
# Tensorflow
#
#     Font: 71.94922637939453
#     Font Size: 394.63287353515625
#     Rectangle: 188.5613250732422
#
#   Text Block 16
#     Text: Python for Everyone
# HTML & CSS
# Introduction to Javascript
# Mathematics for Machine Learning
# Machine Learning with Pyhton
# Python Libraries for Data science
# Flask web development
# CNN & RNN Architectures
# SQL - MySQL
# NLP for Beginners
#
#     Font: 75.23945617675781
#     Font Size: 553.9786376953125
#     Rectangle: 209.84986877441406
#
#   Text Block 17
#     Text: Teachnook - Python developer
#
#     Font: 285.67742919921875
#     Font Size: 459.7764587402344
#     Rectangle: 434.46441650390625
#
#   Text Block 18
#     Text: Code Clause - Project Intern
#
#     Font: 285.161376953125
#     Font Size: 340.5067443847656
#     Rectangle: 423.8448181152344
#
#   Text Block 19
#     Text: St.Joseph's College of Engineering
#
#     Font: 57.81295394897461
#     Font Size: 273.6733703613281
#     Rectangle: 223.55079650878906
#
#   Text Block 20
#     Text: A.R.L.M .Matric .Hr.Sec.School
#
#     Font: 57.81295394897461
#     Font Size: 324.294677734375
#     Rectangle: 204.93809509277344
#
#   Text Block 21
#     Text:  Niograph - Intern
#
#     Font: 281.8230895996094
#     Font Size: 267.6733703613281
#     Rectangle: 371.4698791503906
#
#   Text Block 22
#     Text: As a Data science intern I worked on company customer-
# relationship-management project which involves scrapping data
# from website, storing in database, building machine learning model
# to predict the target customers and vizualizing dashboards to
# understand the insights from the data..
#
#     Font: 289.0247802734375
#     Font Size: 281.61376953125
#     Rectangle: 548.7460327148438
#
#   Text Block 23
#     Text: Age and Gender detection - Uses human face as input image and
# predicts the age and gender which uses 3 - CNN and 3 dense layers
# with 60 epochs of batch size 128,the image size was 128x128
# grayscale format.The network was able to perform better at
# determining gender but not in age due to  small amount of data for
# each age groups.
#  Phishing URLClassification -  Detects whether the url is either
# safe or unsafe since millions of domains are registered per day and
# need for security is required by using random forest algorithm with
# the accuracy of 89%.The main issue faced is  to preprocess the
# data by breaking the url based on constrains like google
# indexed,protocols,etc.
# Face Emotion detection - Classifies the emotions of face in
# realtime(CV) by initially detecting the face and applying the CNN
# model.The dataset contains 28k training images with 4-CNN
# layers,3 dense layers of 80 epochs with accuracy of 79% accuracy
#  Autism Prediction - Collected data from different sources and
# analyzed the key factors of the mental disorder as features to build
# an ML model that classifies positive or negative with calculation of
# autism score.
#
#     Font: 296.8475036621094
#     Font Size: 557.7192993164062
#     Rectangle: 546.7935791015625
#
#   Text Block 24
#     Text: HONORS
#
#     Font: 53.27189636230469
#     Font Size: 672.6344604492188
#     Rectangle: 119.90172576904297
#
#   Text Block 25
#     Text: Winner at Hackforworld conducted by
# Central University of Haryana
# UIpath Hakathon - First place
# Participation of CyberHavoc
# Spoken tutorial Python Exam -IIT
# Bomaby -80%
#
#     Font: 69.90860748291016
#     Font Size: 696.7796630859375
#     Rectangle: 218.97442626953125
#
#   Text Block 26
#     Text: hari-sudhan-20373a224
#
#     Font: 401.9695129394531
#     Font Size: 100.75968933105469
#     Rectangle: 526.6939697265625
#
#   Text Block 27
#     Text: github.com/Harisudhan5
#
#     Font: 392.6307373046875
#     Font Size: 60.069671630859375
#     Rectangle: 526.6992797851562
#
#   Text Block 28
#     Text: The Sparks Foundation -Data Science Intern
# Being Data Science intern ,I worked with Machine Learning Projects
# and Regression problem and solve Regression case problems.
#
#     Font: 286.5746154785156
#     Font Size: 421.7142028808594
#     Rectangle: 540.125
#
#   Image 1
#     Rectangle: 264
#     Width: 396
#     Height: 728
#     Colorspace: 800

# %% [markdown]
# ## PDF Miner
